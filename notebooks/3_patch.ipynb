# %%
from pathlib import Path

import pandas as pd

# %%
CSV_BASE = Path('').resolve().parent / 'csv'

# %%
df_running_log_preupdate = pd.read_csv(CSV_BASE / 'running_log_preupdate.csv')
df_running_log_preupdate.head()

# %%
df_running_log_preupdate.shape

# %%
df_to_add = pd.read_csv(CSV_BASE / 'additional_rows_for_running_log.csv')
df_to_add.head()

# %%
df_to_add.shape

# %%
df = pd.concat([df_running_log_preupdate, df_to_add])

# %%
df.head()

# %%
df.shape

# %%
df = df.drop(columns='Unnamed: 0')
df.to_csv(CSV_BASE / 'running_log_postupdate.csv', index=False)
